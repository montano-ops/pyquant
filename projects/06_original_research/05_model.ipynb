# %% [markdown]
# # Capstone 6 — Original Research — Model / signal construction
#
# **Source paper:** A paper *you* choose (or an original hypothesis of your own)
#
# **Prerequisites:** All modules + at least one prior capstone
#
# Build the signal or model. Keep parameters explicit and centralized so sensitivity tests (07) are possible.
#
# > Research standard: keep `RESEARCH_LOG.md` (in this folder) up to date as you go.
# > Every decision you make after seeing a result gets a dated entry — that is the
# > paper trail that separates honest research from data snooping.

# %%
import numpy as np
import pandas as pd
