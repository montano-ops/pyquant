# %% [markdown]
# # Capstone 2 — Short-Term Reversal — Results
#
# **Source paper:** Jegadeesh (1990), Lehmann (1990) — weekly/monthly reversal studies
#
# **Prerequisites:** Modules 05, 10 (strategy research), 12, 13
#
# Final tables and figures: performance metrics, statistical significance, economic significance after costs. Separate exploration from confirmation.
#
# > Research standard: keep `RESEARCH_LOG.md` (in this folder) up to date as you go.
# > Every decision you make after seeing a result gets a dated entry — that is the
# > paper trail that separates honest research from data snooping.

# %%
import numpy as np
import pandas as pd
